# %% [markdown]
# ### Pivot and PivotTable in Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# %%
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index="foo",columns="bar")
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %%
df_pivoted = df.pivot(index="foo",columns="bar",values="baz")

# %%
grand_total = df_pivoted['A'] + df_pivoted['B'] + df_pivoted['C']
grand_total
# Out:
# foo
# one     6
# two    15
# dtype: int64

# %%
df_salesData = pd.read_excel("supermarket_sales.xlsx")

# %%
df_salesData
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date      Time      Payment    cogs  gross margin percentage  \
# 0   2019-01-05  13:08:00      Ewallet  522.83                 4.761905
# 1   2019-03-08  10:29:00         Cash   76.40                 4.761905
# 2   2019-03-03  13:23:00  Credit card  324.31                 4.761905
# 3   2019-01-27  20:33:00      Ewallet  465.76                 4.761905
# 4   2019-02-08  10:37:00      Ewallet  604.17                 4.761905
# ..         ...       ...          ...     ...                      ...
# 995 2019-01-29  13:46:00      Ewallet   40.35                 4.761905
# 996 2019-03-02  17:16:00      Ewallet  973.80                 4.761905
# 997 2019-02-09  13:22:00         Cash   31.84                 4.761905
# 998 2019-02-22  15:33:00         Cash   65.82                 4.761905
# 999 2019-02-18  13:28:00         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
male_female = df_salesData.groupby("Gender")

# %%
male_female.sum()
# Out:
#         Unit price  Quantity    Tax 5%       Total       cogs  \
# Gender
# Female    27687.24      2869  7994.425  167882.925  159888.50
# Male      27984.89      2641  7384.944  155083.824  147698.88
#
#         gross margin percentage  gross income  Rating
# Gender
# Female              2385.714286      7994.425  3489.2
# Male                2376.190476      7384.944  3483.5

# %%
df_salesData['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df_salesData.pivot_table(index="Gender",aggfunc="sum")
# Out:
#         Quantity  Rating    Tax 5%       Total  Unit price       cogs  \
# Gender
# Female      2869  3489.2  7994.425  167882.925    27687.24  159888.50
# Male        2641  3483.5  7384.944  155083.824    27984.89  147698.88
#
#         gross income  gross margin percentage
# Gender
# Female      7994.425              2385.714286
# Male        7384.944              2376.190476

# %%
## qty sold by male vs female customers
df_salesData.pivot_table(index="Gender",
                         values=["Quantity","cogs","Total"],
                         aggfunc="sum")
# Out:
#         Quantity       Total       cogs
# Gender
# Female      2869  167882.925  159888.50
# Male        2641  155083.824  147698.88

# %%
## in average male and female rating is the same
round(df_salesData.pivot_table(index="Gender",
                         values=["Unit price","Rating"],
                         aggfunc="mean"),2)
# Out:
#         Rating  Unit price
# Gender
# Female    6.96       55.26
# Male      6.98       56.08

# %%
## showing qty sold and total spending by product line
productline_spending = df_salesData.pivot_table(index="Gender",
                         columns="Product line",
                         values=["Quantity","Total"],
                         aggfunc="sum")
productline_spending
# Out:
#                            Quantity                                         \
# Product line Electronic accessories Fashion accessories Food and beverages
# Gender
# Female                          488                 530                514
# Male                            483                 372                438
#
#                                                                      \
# Product line Health and beauty Home and lifestyle Sports and travel
# Gender
# Female                     343                498               496
# Male                       511                413               424
#
#                               Total                                         \
# Product line Electronic accessories Fashion accessories Food and beverages
# Gender
# Female                   27102.0225           30437.400         33170.9175
# Male                     27235.5090           23868.495         22973.9265
#
#
# Product line Health and beauty Home and lifestyle Sports and travel
# Gender
# Female              18560.9865         30036.8775        28574.7210
# Male                30632.7525         23825.0355        26548.1055

# %%
tax_spending_by_city = df_salesData.pivot_table(index="Gender",
                         columns="City",
                         values=["Tax 5%","Total"],
                         aggfunc="sum")
tax_spending_by_city
# Out:
#           Tax 5%                            Total
# City    Mandalay  Naypyitaw     Yangon   Mandalay   Naypyitaw      Yangon
# Gender
# Female  2520.395  2937.4030  2536.6270  52928.295  61685.4630  53269.1670
# Male    2536.637  2327.7735  2520.5335  53269.377  48883.2435  52931.2035

# %%
populationData = pd.read_csv("population_total.csv",sep=",")

# %%
populationData
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
populationData.dropna(inplace=True)

# %%
populationData
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4178 rows x 3 columns]

# %%
df_reshaped = populationData.pivot(index="year",columns="country",values="population")

# %%
df_reshaped.head(n=10)
# Out:
# country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# year
# 1955.0     8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0     8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0     9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0    11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0    12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0    13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0    11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0    12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0    18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0    20779953.0  3129243.0  31042235.0         57821.0  65390.0
#
# country      Angola  Anguilla  Antigua and Barbuda   Argentina    Armenia  \
# year
# 1955.0    5043247.0    5783.0              49648.0  18789418.0  1563507.0
# 1960.0    5454933.0    6032.0              54131.0  20481779.0  1874121.0
# 1965.0    5770570.0    6361.0              58698.0  22159650.0  2211319.0
# 1970.0    5890365.0    6771.0              64177.0  23880561.0  2525068.0
# 1975.0    7024000.0    7159.0              62675.0  25865776.0  2832759.0
# 1980.0    8341289.0    7285.0              61865.0  27896528.0  3099754.0
# 1985.0    9961997.0    7293.0              61786.0  30216279.0  3335940.0
# 1990.0   11848386.0    8899.0              62528.0  32618651.0  3538171.0
# 1995.0   13945206.0    9866.0              68670.0  34828170.0  3217348.0
# 2000.0   16395473.0   11252.0              76016.0  36870787.0  3069591.0
#
# country  ...    Uruguay  Uzbekistan   Vanuatu   Venezuela     Vietnam  \
# year     ...
# 1955.0   ...  2372559.0   7277333.0   54921.0   6744695.0  28147443.0
# 1960.0   ...  2538643.0   8526300.0   63689.0   8141841.0  32670039.0
# 1965.0   ...  2694536.0  10116870.0   74270.0   9692278.0  37858951.0
# 1970.0   ...  2809793.0  12080317.0   85377.0  11396393.0  43404793.0
# 1975.0   ...  2830176.0  13857478.0   99859.0  13189509.0  48718189.0
# 1980.0   ...  2915389.0  15898757.0  115597.0  15182611.0  54281846.0
# 1985.0   ...  3011519.0  18061284.0  129984.0  17319520.0  60896721.0
# 1990.0   ...  3109601.0  20398348.0  146573.0  19632665.0  67988862.0
# 1995.0   ...  3224281.0  22791026.0  168158.0  21931084.0  74910461.0
# 2000.0   ...  3319736.0  24769955.0  184972.0  24192446.0  79910412.0
#
# country  Wallis & Futuna  Western Sahara       Yemen      Zambia    Zimbabwe
# year
# 1955.0            7669.0         21147.0   4965574.0   2644976.0   3213286.0
# 1960.0            8157.0         32761.0   5315355.0   3070776.0   3776681.0
# 1965.0            8724.0         50970.0   5727751.0   3570464.0   4471177.0
# 1970.0            8853.0         76874.0   6193384.0   4179067.0   5289303.0
# 1975.0            9320.0         74954.0   6784695.0   4943283.0   6293875.0
# 1980.0           11231.0        150877.0   7941898.0   5851825.0   7408624.0
# 1985.0           13622.0        182421.0   9572175.0   6923149.0   8877489.0
# 1990.0           13800.0        217258.0  11709993.0   8036845.0  10432421.0
# 1995.0           14149.0        255634.0  14913315.0   9096607.0  11410714.0
# 2000.0           14694.0        314118.0  17409072.0  10415944.0  11881477.0
#
# [10 rows x 234 columns]

# %%
df_selected_country = df_reshaped[["United States","Russia", "Brazil","China","Canada","Nigeria"]]
df_selected_country
# Out:
# country  United States       Russia       Brazil         China      Canada  \
# year
# 1955.0     171685336.0  111355300.0   62533919.0  6.122416e+08  15673763.0
# 1960.0     186720571.0  119871700.0   72179226.0  6.604081e+08  17847405.0
# 1965.0     199733676.0  126503736.0   83373530.0  7.242190e+08  19627980.0
# 1970.0     209513341.0  130148653.0   95113265.0  8.276014e+08  21374326.0
# 1975.0     219081251.0  133804858.0  107216205.0  9.262409e+08  23059265.0
# 1980.0     229476354.0  138053150.0  120694009.0  1.000089e+09  24416886.0
# 1985.0     240499825.0  142957284.0  135274080.0  1.075589e+09  25744810.0
# 1990.0     252120309.0  147531561.0  149003223.0  1.176884e+09  27541319.0
# 1995.0     265163745.0  148227466.0  162019896.0  1.240921e+09  29164152.0
# 2000.0     281710909.0  146404903.0  174790340.0  1.290551e+09  30588383.0
# 2005.0     294993511.0  143672116.0  186127103.0  1.330776e+09  32164309.0
# 2010.0     309011475.0  143479274.0  195713635.0  1.368811e+09  34147564.0
# 2015.0     320878310.0  144985057.0  204471769.0  1.406848e+09  36026676.0
# 2016.0     323015995.0  145275383.0  206163053.0  1.414049e+09  36382944.0
# 2017.0     325084756.0  145530082.0  207833823.0  1.421022e+09  36732095.0
# 2018.0     327096265.0  145734038.0  209469323.0  1.427648e+09  37074562.0
# 2019.0     329064917.0  145872256.0  211049527.0  1.433784e+09  37411047.0
# 2020.0     331002651.0  145934462.0  212559417.0  1.439324e+09  37742154.0
#
# country      Nigeria
# year
# 1955.0    41086100.0
# 1960.0    45138458.0
# 1965.0    50127921.0
# 1970.0    55982144.0
# 1975.0    63374298.0
# 1980.0    73423633.0
# 1985.0    83562785.0
# 1990.0    95212450.0
# 1995.0   107948335.0
# 2000.0   122283850.0
# 2005.0   138865016.0
# 2010.0   158503197.0
# 2015.0   181137448.0
# 2016.0   185960241.0
# 2017.0   190873244.0
# 2018.0   195874683.0
# 2019.0   200963599.0
# 2020.0   206139589.0

# %%
df_selected_country = df_selected_country.astype(int)

# %%
df_selected_country.index
# Out:
# Float64Index([1955.0, 1960.0, 1965.0, 1970.0, 1975.0, 1980.0, 1985.0, 1990.0,
#               1995.0, 2000.0, 2005.0, 2010.0, 2015.0, 2016.0, 2017.0, 2018.0,
#               2019.0, 2020.0],
#              dtype='float64', name='year')

# %% [markdown]
# ### Lineplot

# %%
df_selected_country.plot(kind="line",
                         xlabel="Year",
                         ylabel="Population",
                         title="Population 1955 - 2020",
                        figsize=(10,6))
plt.savefig("barchart_population.png")

# %% [markdown]
# ### Area Plot

# %%
df_selected_country.plot(kind="area",
                         xlabel="Year",
                         ylabel="Population",
                         title="Population 1955 - 2020",
                        figsize=(10,6))
plt.show()

# %% [markdown]
# ### Bar chart

# %%
##grab index row of 2020 and transpose the DataFrame to make a barplot
barplot = df_selected_country[df_selected_country.index.isin([2020])]
barplot = barplot.T

# %%
barplot.plot(kind="bar",
             xlabel="Year",
             ylabel="Population",
             title="Population 2020",
             color="green",
             figsize=(10,7))
plt.savefig("barchart_population.png")

# %%
df_selected_country.plot(kind="bar",
             xlabel="Year",
             ylabel="Population",
             title="Population 1955 - 2020",
             figsize=(10,7))
plt.show()

# %%
barplot_5yrs = df_selected_country[df_selected_country.index.isin([2016,2017,2018,2019,2020])]
barplot_5yrs
# Out:
# country  United States     Russia     Brazil       China    Canada    Nigeria
# year
# 2016.0       323015995  145275383  206163053  1414049351  36382944  185960241
# 2017.0       325084756  145530082  207833823  1421021791  36732095  190873244
# 2018.0       327096265  145734038  209469323  1427647786  37074562  195874683
# 2019.0       329064917  145872256  211049527  1433783686  37411047  200963599
# 2020.0       331002651  145934462  212559417  1439323776  37742154  206139589

# %%
##transpose the dataframe before making a bar plot so as to use column data as index
barplot_5yrs = barplot_5yrs.T

# %%
barplot_5yrs.plot(kind="bar",
             xlabel="Year",
             ylabel="Population",
             title="Population 2015 - 2020",
             figsize=(10,7))
plt.savefig("5yrs_population.png")

# %%
##rename the init column name to a str 
pieChart = barplot.rename(columns={2020:"2020"})
pieChart.plot(kind="pie",subplots=True)
plt.savefig("PieChart_population.png")
